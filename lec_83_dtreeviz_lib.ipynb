# %%
# !pip install dtreeviz==1.3.7
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting dtreeviz==1.3.7
#   Downloading dtreeviz-1.3.7.tar.gz (62 kB)
#      ---------------------------------------- 0.0/62.5 kB ? eta -:--:--
#      ------------------ ------------------- 30.7/62.5 kB 660.6 kB/s eta 0:00:01
#      ------------------ ------------------- 30.7/62.5 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 62.5/62.5 kB 479.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: graphviz>=0.9 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from dtreeviz==1.3.7) (0.20.3)
# Requirement already satisfied: pandas in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from dtreeviz==1.3.7) (2.2.3)
# Requirement already satisfied: numpy in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from dtreeviz==1.3.7) (1.24.0)
# Requirement already satisfied: scikit-learn in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from dtreeviz==1.3.7) (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from dtreeviz==1.3.7) (3.10.1)
# Requirement already satisfied: colour in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from dtreeviz==1.3.7) (0.1.5)
# Requirement already satisfied: pytest in d:\programdata\anaconda3\lib\site-packages (from dtreeviz==1.3.7) (7.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from matplotlib->dtreeviz==1.3.7) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from pandas->dtreeviz==1.3.7) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from pandas->dtreeviz==1.3.7) (2025.2)
# Requirement already satisfied: iniconfig in d:\programdata\anaconda3\lib\site-packages (from pytest->dtreeviz==1.3.7) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in d:\programdata\anaconda3\lib\site-packages (from pytest->dtreeviz==1.3.7) (1.0.0)
# Requirement already satisfied: colorama in d:\programdata\anaconda3\lib\site-packages (from pytest->dtreeviz==1.3.7) (0.4.6)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from scikit-learn->dtreeviz==1.3.7) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from scikit-learn->dtreeviz==1.3.7) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from scikit-learn->dtreeviz==1.3.7) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\rishikesh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz==1.3.7) (1.17.0)
# Building wheels for collected packages: dtreeviz
#   Building wheel for dtreeviz (setup.py): started
#   Building wheel for dtreeviz (setup.py): finished with status 'done'
#   Created wheel for dtreeviz: filename=dtreeviz-1.3.7-py3-none-any.whl size=68145 sha256=4fa06c94414eebce9b810cb8f6ae55d01490205800af8cc0d33ee1eee0654a4a
#   Stored in directory: c:\users\rishikesh\appdata\local\pip\cache\wheels\81\9d\73\9dd9428a0adbdf2e031c9e4adc29b7cc2a872eeb274d60434f
# Successfully built dtreeviz
# Installing collected packages: dtreeviz
#   Attempting uninstall: dtreeviz
#     Found existing installation: dtreeviz 2.2.2
#     Uninstalling dtreeviz-2.2.2:
#       Successfully uninstalled dtreeviz-2.2.2
# Successfully installed dtreeviz-1.3.7

# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

# %%
clas = tree.DecisionTreeClassifier()  
iris = load_iris()

# %%
X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
                       max_depth=None, max_features=None, max_leaf_nodes=None,
                       min_impurity_decrease=0.0,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, 
                       random_state=None, splitter='best')
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clas)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.46153846153846156, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6153846153846154, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.5833333333333334, 'x[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(0.7692307692307693, 0.4166666666666667, 'x[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.4166666666666667, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]
