# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train1.csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %% [markdown]
# ## numerical data

# %%
x  = df.drop(columns=['Survived'])
y = df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train['age_imputed']=x_train['Age']
x_test['age_imputed']=x_test['Age']

# %%
x_train
# Out:
#       Age      Fare  age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125          NaN
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792          NaN
# 168   NaN   25.9250          NaN
#
# [712 rows x 3 columns]

# %%
x_train['age_imputed'][x_train['age_imputed'].isnull()]=x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
x_test['age_imputed'][x_test['age_imputed'].isnull()]=x_test['Age'].dropna().sample(x_test['Age'].isnull().sum()).values

# %%
x_train['age_imputed'][x_train['age_imputed'].isnull()]
# Out:
# Series([], Name: age_imputed, dtype: float64)

# %%
x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
# Out:
# array([ 3. , 16. , 34. , 24. , 33. , 35. , 22. , 32. , 41. , 44. , 26. ,
#        45. , 19. , 21. ,  2. , 24. , 28. , 36. , 35. ,  5. , 29. , 45.5,
#        33. , 24. , 58. , 25. , 33. , 29. , 22. , 70.5, 17. , 27. , 23. ,
#        17. , 62. , 18. , 24. , 20. , 30. , 30. , 26. , 28.5,  3. , 42. ,
#        45. , 16. , 33. , 30. , 16. , 40. , 36. , 36. , 45. , 18. , 59. ,
#        42. , 32. , 34. ,  9. , 19. , 20. , 26. , 52. , 35. , 30. , 38. ,
#        47. ,  2. , 31. , 40. ,  1. , 27. ,  6. , 54. , 34. , 17. , 28. ,
#        33. ,  2. , 17. , 31. , 39. , 40.5, 27. , 65. , 32. , 35. , 30. ,
#        40. , 38. , 25. ,  1. , 25. ,  7. , 31. , 21. , 32. , 29. , 15. ,
#        18. , 25. , 44. , 16. , 27. , 33. , 22. , 37. , 36. , 31. , 36. ,
#        62. , 31. , 34. , 35. , 42. , 36. , 20. , 29. , 16. , 19. , 24. ,
#         4. , 21. ,  3. , 28. , 40. , 52. , 30. , 22. ,  9. , 28. ,  8. ,
#         9. , 14. ,  4. , 23. , 62. , 39. , 33. , 47. , 36.5, 35. , 34. ,
# ...

# %%
x_train['Age'].isnull().sum()
# Out:
# 148

# %%
x_train
# Out:
#       Age      Fare  age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         29.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         19.0
# 168   NaN   25.9250         40.5
#
# [712 rows x 3 columns]

# %%
sns.distplot(x_train['Age'],label='Original')
sns.distplot(x_train['age_imputed'],label='Imputed')

plt.legend()
plt.show()
# Out:
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\2437980987.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train['Age'],label='Original')
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\2437980987.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.distplot(x_train['Age'],label='Original',hist=False)
sns.distplot(x_train['age_imputed'],label='Imputed',hist=False)

plt.legend()
plt.show()
# Out:
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\2097451597.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train['Age'],label='Original',hist=False)
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\2097451597.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
print("Original variable variance is ",x_train['Age'].var())
print("Variance after random imputation",x_train['age_imputed'].var())
# Out:
# Original variable variance is  204.3495133904614
# Variance after random imputation 197.83634903502755

# %%
x_train[['Fare','Age','age_imputed']].cov()
# Out:
#                     Fare         Age  age_imputed
# Fare         2368.246832   71.512440    46.813340
# Age            71.512440  204.349513   204.349513
# age_imputed    46.813340  204.349513   197.836349

# %%
x_train[['Age','age_imputed']].boxplot()
# Out:
# <Axes: >

# %%
#sampled_value = x_train['Age'].dropna().sample(1,random_state=int(observation['Fare']))

# %% [markdown]
# ## categorical data

# %%
data = pd.read_csv('house-train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
data.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
data.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
x = data
y = data['SalePrice']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train['GarageQual_imputed'] = x_train['GarageQual']
x_test['GarageQual_imputed'] = x_test['GarageQual']

x_train['FireplaceQu_imputed'] = x_train['FireplaceQu']
x_test['FireplaceQu_imputed'] = x_test['FireplaceQu']

# %%
x_train['GarageQual_imputed'][x_train['GarageQual_imputed'].isnull()]=x_train['GarageQual'].dropna().sample(x_train['GarageQual'].isnull().sum()).values
x_test['GarageQual_imputed'][x_test['GarageQual_imputed'].isnull()]=x_test['GarageQual'].dropna().sample(x_test['GarageQual'].isnull().sum()).values

x_train['FireplaceQu_imputed'][x_train['FireplaceQu_imputed'].isnull()]=x_train['FireplaceQu'].dropna().sample(x_train['FireplaceQu'].isnull().sum()).values
x_test['FireplaceQu_imputed'][x_test['FireplaceQu_imputed'].isnull()]=x_test['FireplaceQu'].dropna().sample(x_test['FireplaceQu'].isnull().sum()).values
# Out:
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\3674334412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['GarageQual_imputed'][x_train['GarageQual_imputed'].isnull()]=x_train['GarageQual'].dropna().sample(x_train['GarageQual'].isnull().sum()).values
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\3674334412.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['GarageQual_imputed'][x_test['GarageQual_imputed'].isnull()]=x_test['GarageQual'].dropna().sample(x_test['GarageQual'].isnull().sum()).values
# ...

# %%
temp = pd.concat([
    x_train['GarageQual'].values_counts()/len(x_train['GarageQual'].dropna()),
    x_train['GarageQual_imputed'].values_counts()/len(x_train)
    
],
axis=1)

temp.columns=['original','imputed']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23340\3729261787.py in ?()
#       1 temp = pd.concat([
# ----> 2     x_train['GarageQual'].values_counts()/len(x_train['GarageQual'].dropna()),
#       3     x_train['GarageQual_imputed'].values_counts()/len(x_train)
#       4
#       5 ],
#
# D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'values_counts'

# %%
temp = pd.concat([
    x_train['FireplaceQu'].values_counts()/len(x_train['FireplaceQu'].dropna()),
    x_train['FireplaceQu_imputed'].values_counts()/len(x_train)
    
],
axis=1)

temp.columns=['original','imputed']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23340\3877764186.py in ?()
#       1 temp = pd.concat([
# ----> 2     x_train['FireplaceQu'].values_counts()/len(x_train['FireplaceQu'].dropna()),
#       3     x_train['FireplaceQu_imputed'].values_counts()/len(x_train)
#       4
#       5 ],
#
# D:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'values_counts'

# %%
for category in x_train['FireplaceQu'].dropna().unique():
    sns.distplot(x_train[x_train['FireplaceQu']== category]['SalePrice'],hist=False,label=category)
plt.show()
# Out:
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\3253612511.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[x_train['FireplaceQu']== category]['SalePrice'],hist=False,label=category)
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\3253612511.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
for category in x_train['FireplaceQu_imputed'].dropna().unique():
    sns.distplot(x_train[x_train['FireplaceQu_imputed']== category]['SalePrice'],hist=False,label=category)
plt.show()
# Out:
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\4117798256.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[x_train['FireplaceQu_imputed']== category]['SalePrice'],hist=False,label=category)
# C:\Users\Rishikesh\AppData\Local\Temp\ipykernel_23340\4117798256.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...
